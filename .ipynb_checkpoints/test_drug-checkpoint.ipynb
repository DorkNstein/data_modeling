# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import dateutil

# %%
def dateparse(x):
    return pd.datetime.strptime(x, '%Y-%m')

data = pd.read_csv('input/drug_purchases.csv', parse_dates=['purchase_date'])

# Convert date from string to date times
data[['purchase_month']] = data['purchase_date'].apply(lambda x: pd.Series(x.strftime("%Y-%m")))
data[['purchase_year']] = data['purchase_date'].apply(lambda x: pd.Series(x.strftime("%Y")))


# display(data.dtypes);
data.head()
# Out:
#      id  log_id  layout_id  staging_record_id created_by           created_at  \
# 0   410      46         87                595     SYSTEM  2018-10-08 21:30:06
# 1  2387      46         87               2612     SYSTEM  2018-10-08 21:30:27
# 2  2411      46         87               2587     SYSTEM  2018-10-08 21:30:28
# 3  2436      46         87               2565     SYSTEM  2018-10-08 21:30:28
# 4  2461      46         87               2540     SYSTEM  2018-10-08 21:30:28
#
#   modified_by          modified_at  deleted              address  \
# 0      SYSTEM  2018-10-08 21:30:06    False         5208 98TH ST
# 1      SYSTEM  2018-10-08 21:30:27    False       251 N BROADWAY
# 2      SYSTEM  2018-10-08 21:30:28    False       2040 ROUTE 130
# 3      SYSTEM  2018-10-08 21:30:28    False      5230 DALLAS HWY
# 4      SYSTEM  2018-10-08 21:30:28    False  1704 W HILLSBOROUGH
#
#        ...       unit_price                 drug_name  \
# 0      ...           0.1327     PANTOPRAZOLE TAB 40MG
# 1      ...           0.2450       PREDNISONE TAB 10MG
# 2      ...           0.2734     ATORVASTATIN TAB 10MG
# 3      ...         304.5100  TUDORZA PRES AER 400/ACT
# 4      ...           0.1813     PANTOPRAZOLE TAB 40MG
#
#                                 drug_class  state   drug_indication  \
# 0                              ULCER DRUGS     TX             Ulcer
# 1                          CORTICOSTEROIDS     NJ      Inflammation
# 2                      ANTIHYPERLIPIDEMICS     NJ  High Cholesterol
# 3  ANTIASTHMATIC AND BRONCHODILATOR AGENTS     GA            Asthma
# 4                              ULCER DRUGS     FL             Ulcer
#
#   person_code         pharmacy       zip purchase_month purchase_year
# 0    17546398     CVS PHARMACY     79424        2016-01          2016
# 1    17427509   SAVON PHARMACY      8070        2016-01          2016
# 2    17112961  EXPRESS SCRIPTS  80169716        2016-01          2016
# 3    17427513  WALGREENS #6325     30127        2016-01          2016
# 4    17106797  WALGREENS #6611     33603        2016-01          2016
#
# [5 rows x 26 columns]

# %%
from fbprophet import Prophet

m_df = data[['purchase_month', 'unit_price']]


m_df = pd.DataFrame({'unit_price' : m_df.groupby(["purchase_month"])['unit_price'].sum()}).reset_index()

display(m_df.dtypes)

# m_df['purchase_month'] = m_df['purchase_month'].apply(dateutil.parser.parse, dayfirst=True)

m_df1 = m_df.copy()
m_df1.rename(columns={'purchase_month': 'ds',
                   'unit_price': 'y'},
          inplace=True)

m_df1.head()
# Out:
# purchase_month     object
# unit_price        float64
# dtype: object
#         ds            y
# 0  2016-01   61704.4785
# 1  2016-02   71601.1962
# 2  2016-03   78170.8829
# 3  2016-04  103794.4647
# 4  2016-05  105521.8570

# %%
m = Prophet()
m.fit(m_df1)
m_forecast = m.make_future_dataframe(periods=365, freq='D')
m_forecast = m.predict(m_forecast)

display(m_forecast.head())
display(m_forecast.tail())
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         trend    yhat_lower     yhat_upper   trend_lower  \
# 0 2016-01-01  76341.383731  40879.880199   85833.215317  76341.383731
# 1 2016-02-01  77559.801449  43281.001574   88640.420246  77559.801449
# 2 2016-03-01  78699.611546  64345.770742  109097.226379  78699.611546
# 3 2016-04-01  79918.029287  64824.954445  111206.398872  79918.029287
# 4 2016-05-01  81097.143236  72928.166108  117173.964357  81097.143236
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  76341.383731   -11126.972294         -11126.972294         -11126.972294
# 1  77559.801449   -11108.883463         -11108.883463         -11108.883463
# 2  78699.611546     7561.680325           7561.680325           7561.680325
# 3  79918.029287     9319.298215           9319.298215           9319.298215
# 4  81097.143236    13911.850279          13911.850279          13911.850279
#
#          yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0 -11126.972294 -11126.972294 -11126.972294                   0.0
# 1 -11108.883463 -11108.883463 -11108.883463                   0.0
# 2   7561.680325   7561.680325   7561.680325                   0.0
# 3   9319.298215   9319.298215   9319.298215                   0.0
# 4  13911.850279  13911.850279  13911.850279                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  65214.411437
# 1                         0.0                         0.0  66450.917986
# 2                         0.0                         0.0  86261.291871
# 3                         0.0                         0.0  89237.327502
# 4                         0.0                         0.0  95008.993516
#            ds          trend    yhat_lower     yhat_upper    trend_lower  \
# 88 2018-10-27  116824.426197  81448.550075  127787.961743  116824.425491
# 89 2018-10-28  116863.730306  82456.309402  128601.239367  116863.729571
# 90 2018-10-29  116903.034415  81248.902237  127805.666548  116903.033671
# 91 2018-10-30  116942.338525  83647.920022  131450.891703  116942.337771
# 92 2018-10-31  116981.642634  83796.012248  131012.367194  116981.641856
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 88  116824.427018   -11730.249765         -11730.249765         -11730.249765
# 89  116863.731134   -11296.538722         -11296.538722         -11296.538722
# 90  116903.035272   -10801.269745         -10801.269745         -10801.269745
# 91  116942.339400   -10267.874516         -10267.874516         -10267.874516
# 92  116981.643551    -9720.520092          -9720.520092          -9720.520092
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 88 -11730.249765 -11730.249765 -11730.249765                   0.0
# 89 -11296.538722 -11296.538722 -11296.538722                   0.0
# 90 -10801.269745 -10801.269745 -10801.269745                   0.0
# 91 -10267.874516 -10267.874516 -10267.874516                   0.0
# 92  -9720.520092  -9720.520092  -9720.520092                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper           yhat
# 88                         0.0                         0.0  105094.176432
# 89                         0.0                         0.0  105567.191584
# 90                         0.0                         0.0  106101.764670
# 91                         0.0                         0.0  106674.464008
# 92                         0.0                         0.0  107261.122542

# %%
fig = m.plot(m_forecast, xlabel='purchase_months', ylabel='Total drug sales price')
plt.title('Drug Market')
plt.show()

m.plot_components(m_forecast)
plt.show()

# %%
# How many rows the dataset
data['id'].count()
# Out:
# 184250

# %%
# What was the highest unit_price?
data['unit_price'].max()
# Out:
# 32032.06

# %%
# How many entries are there for each month?
data['drug_indication'].value_counts();

# %%
data['drug_class'].value_counts();

# %%
data['person_code'].value_counts();

# %%
data['pharmacy'].value_counts();

# %%
data['state'].value_counts();

# %%
data.groupby(['person_code', 'pharmacy'])['id'].count();

# %%
data.groupby(['state', 'pharmacy'])['purchase_date'].count();

# %%
data['purchase_date'].value_counts();

# %%
data['purchase_month'].value_counts();

# %%
data.groupby(['drug_class', 'purchase_month'])['id'].count();

# %%
data.groupby(['state', 'purchase_month'])['id'].count();

# %%
grouped = data.groupby(['state', 'purchase_month'])['id'].count().reset_index(name='count').sort_values(['state','count'], ascending=[True, False]).groupby('state').head(5)
grouped;

# %%
data.groupby(['person_code', 'purchase_month'])['id'] \
    .count() \
    .reset_index(name='count') \
    .sort_values(['person_code','count', 'purchase_month'], ascending=[True, False, False]) \
    .groupby('person_code').head(5);

# %%
data.groupby(['state', 'purchase_month'])['id'] \
    .count() \
    .reset_index(name='count') \
    .sort_values(['state','count', 'purchase_month'], ascending=[True, False, False]) \
    .groupby('state').head(5);

# %%
data.groupby(['state', 'purchase_year'])['id'] \
    .count() \
    .reset_index(name='count') \
    .sort_values(['state','count', 'purchase_year'], ascending=[True, False, False]) \
    .groupby('state').head(5);

# %%
data.groupby(['person_code', 'purchase_year'])['id'] \
    .count() \
    .reset_index(name='count') \
    .sort_values(['person_code','count', 'purchase_year'], ascending=[True, False, False]) \
    .groupby('person_code').head(5);
